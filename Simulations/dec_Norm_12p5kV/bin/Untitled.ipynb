# %%
import matplotlib.pyplot as plt

f = open("fort.205",'r')
lines = f.readlines()
t = []
signal = []
for l in lines:
    t.append(float(l.split()[0]))
    signal.append(float(l.split()[1]))
# print(t)
plt.plot(t,signal)
plt.xlim(1500, 3000)
# Out:
# (1500.0, 3000.0)

# %%
#!/bin/bash

mkdir tof_norm_10kV/

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_328.dat
cp fort.205 tof_norm_10kV/dec_450_328.dat

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_273.dat
cp fort.205 tof_norm_10kV/dec_450_273.dat

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_202.dat
cp fort.205 tof_norm_10kV/dec_450_202.dat

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_92.dat
cp fort.205 tof_norm_10kV/dec_450_92.dat

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_49.dat
cp fort.205 tof_norm_10kV/dec_450_49.dat

./bin_yin.exe -i ../fly/fly_norm_10kV/dec_450_30.dat
cp fort.205 tof_norm_10kV/dec_450_30.dat
